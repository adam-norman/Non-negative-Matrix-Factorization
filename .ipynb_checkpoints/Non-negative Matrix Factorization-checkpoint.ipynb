# %%
import pandas as pd

# %%
df=pd.read_csv('datasets/npr.csv',sep='\t')
df.head()
# Out:
#                                              Article
# 0  In the Washington of 2016, even when the polic...
# 1    Donald Trump has used Twitter  —   his prefe...
# 2    Donald Trump is unabashedly praising Russian...
# 3  Updated at 2:50 p. m. ET, Russian President Vl...
# 4  From photography, illustration and video, to d...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')

# %%
docTermMatrix=tfidf.fit_transform(df['Article'])

# %%
docTermMatrix
# Out:
# <11992x54777 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3033388 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import NMF

# %%
nmf_model=NMF(n_components=7,random_state=42)

# %%
nmf_model.fit(dataTermMatrix)
# Out:
# NMF(n_components=7, random_state=42)

# %%
# Grab the highest probability words per topic
for i,t in enumerate(nmf_model.components_):
    print(f'Topic #{i} of maxi 15 words prop.')
    print([ tfidf.get_feature_names()[j] for j in nmf_model.components_[i].argsort()[-15:]])
    print('\n\n')
# Out:
# Topic #0 of maxi 15 words prop.
# ['new', 'research', 'like', 'patients', 'health', 'disease', 'percent', 'women', 'virus', 'study', 'water', 'food', 'people', 'zika', 'says']
#
#
#
# Topic #1 of maxi 15 words prop.
# ['gop', 'pence', 'presidential', 'russia', 'administration', 'election', 'republican', 'obama', 'white', 'house', 'donald', 'campaign', 'said', 'president', 'trump']
#
#
#
# Topic #2 of maxi 15 words prop.
# ['senate', 'house', 'people', 'act', 'law', 'tax', 'plan', 'republicans', 'affordable', 'obamacare', 'coverage', 'medicaid', 'insurance', 'care', 'health']
#
#
#
# Topic #3 of maxi 15 words prop.
# ['officers', 'syria', 'security', 'department', 'law', 'isis', 'russia', 'government', 'state', 'attack', 'president', 'reports', 'court', 'said', 'police']
#
#
#
# Topic #4 of maxi 15 words prop.
# ['primary', 'cruz', 'election', 'democrats', 'percent', 'party', 'delegates', 'vote', 'state', 'democratic', 'hillary', 'campaign', 'voters', 'sanders', 'clinton']
#
#
#
# Topic #5 of maxi 15 words prop.
# ['love', 've', 'don', 'album', 'way', 'time', 'song', 'life', 'really', 'know', 'people', 'think', 'just', 'music', 'like']
#
#
#
# Topic #6 of maxi 15 words prop.
# ['teacher', 'state', 'high', 'says', 'parents', 'devos', 'children', 'college', 'kids', 'teachers', 'student', 'education', 'schools', 'school', 'students']

# %%
Topics=nmf_model.transform(docTermMatrix)

# %%
df['topic']= Topics.argmax(axis=1)

# %%
df[:60]
# Out:
#                                               Article  topic
# 0   In the Washington of 2016, even when the polic...      1
# 1     Donald Trump has used Twitter  —   his prefe...      1
# 2     Donald Trump is unabashedly praising Russian...      1
# 3   Updated at 2:50 p. m. ET, Russian President Vl...      3
# 4   From photography, illustration and video, to d...      6
# 5   I did not want to join yoga class. I hated tho...      5
# 6   With a   who has publicly supported the debunk...      0
# 7   I was standing by the airport exit, debating w...      0
# 8   If movies were trying to be more realistic, pe...      0
# 9   Eighteen years ago, on New Year’s Eve, David F...      5
# 10  For years now, some of the best, wildest, most...      5
# 11  For years now, some of the best, wildest, most...      5
# 12  The Colorado River is like a giant bank accoun...      0
# 13  For the last installment of NPR’s holiday reci...      5
# 14  Being overweight can raise your blood pressure...      0
# 15  Who’s the YouTube star of 2016? Adele singing ...      5
# 16  Here’s a quick roundup of some of the   you ma...      3
# 17  Ben Johnston doesn’t follow the rules of music...      5
# 18  David Bowie, Prince and George Michael are all...      5
# 19  In November, the typically straitlaced Office ...      1
# 20  This is the time of year when everybody is mak...      5
# 21  Terrorist attacks, hurricanes, a divisive U. S...      5
# 22  We all experience stress at work, no matter th...      6
# 23  When John Fahey recorded The New Possibility i...      5
# 24  This year was one of   hacks, exploding smartp...      5
# 25  From West Virginia to Wyoming, coal country ov...      1
# 26  Updated Jan. 1 at 9:56 a. m. ET, At least 39 p...      3
# 27  On the morning of Jan. 1, Los Angeles resident...      3
# 28  In September, reproductive endocrinologist Joh...      0
# 29  In an effort to take advantage of the intimate...      0
# 30  Much has been said about the physical and psyc...      5
# 31  Editor’s note: This post includes language tha...      1
# 32  The   movement, which has been associated with...      5
# 33  On New Year’s Day, Portland restaurant Ava Gen...      5
# 34  U. S. Supreme Court Chief Justice John Roberts...      3
# 35  When Octavia Spencer first read the script for...      5
# 36  If you find yourself at a loss to name even on...      0
# 37  By day, Nicola Berlinsky and sisters Lisa Pime...      6
# 38  It’s that time of year again, when I atone for...      5
# 39  For those of us at NPR, 2016 was   of big news...      5
# 40  Though many of us lamented the   saga of this ...      1
# 41  With so much attention paid to   women in 2016...      5
# 42  As the 115th Congress is sworn in Tuesday, Rep...      1
# 43  Democrats may have lost the House and the Sena...      1
# 44  There’s more methane gas in the atmosphere tha...      0
# 45  A Jewish farming couple from Canada says it ha...      3
# 46  As Donald Trump prepares to become president, ...      1
# 47  The Islamic State issued a statement on Monday...      3
# 48  On a September day in 1940 while much of Europ...      0
# 49  Hundreds came out New Year’s Day to ride the t...      5
# 50  What to expect when you’re expecting a baby di...      0
# 51  John Grant is not your      . He’s a superstar...      5
# 52  Since George Washington penned his farewell ad...      3
# 53  Erica Abad glides down the ancient canals of X...      5
# 54  Congress is back in session on Tuesday, and le...      2
# 55  Almost a million elephants roamed Africa 25 ye...      0
# 56  The second day of January is National Science ...      5
# 57  Creatine, a chemical constituent of meat and f...      0
# 58  Men who work out may be using legal    supplem...      0
# 59  There are a lot of reasons victims of sexual a...      6

# %%
topics_dict={0:'Medicine',1:'Politics1',2:'Politics2',3:'Internal Affairs',4:'topic4',5:'News',6:'Crims'}
df['Topic Label']=df['topic'].map(topics_dict)

# %%
df[:20]
# Out:
#                                               Article  topic       Topic Label
# 0   In the Washington of 2016, even when the polic...      1         Politics1
# 1     Donald Trump has used Twitter  —   his prefe...      1         Politics1
# 2     Donald Trump is unabashedly praising Russian...      1         Politics1
# 3   Updated at 2:50 p. m. ET, Russian President Vl...      3  Internal Affairs
# 4   From photography, illustration and video, to d...      6             Crims
# 5   I did not want to join yoga class. I hated tho...      5              News
# 6   With a   who has publicly supported the debunk...      0          Medicine
# 7   I was standing by the airport exit, debating w...      0          Medicine
# 8   If movies were trying to be more realistic, pe...      0          Medicine
# 9   Eighteen years ago, on New Year’s Eve, David F...      5              News
# 10  For years now, some of the best, wildest, most...      5              News
# 11  For years now, some of the best, wildest, most...      5              News
# 12  The Colorado River is like a giant bank accoun...      0          Medicine
# 13  For the last installment of NPR’s holiday reci...      5              News
# 14  Being overweight can raise your blood pressure...      0          Medicine
# 15  Who’s the YouTube star of 2016? Adele singing ...      5              News
# 16  Here’s a quick roundup of some of the   you ma...      3  Internal Affairs
# 17  Ben Johnston doesn’t follow the rules of music...      5              News
# 18  David Bowie, Prince and George Michael are all...      5              News
# 19  In November, the typically straitlaced Office ...      1         Politics1
